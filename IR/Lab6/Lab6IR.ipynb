# %%
import pandas as pd
# !pip install mlxtend
from mlxtend.frequent_patterns import apriori, fpgrowth
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from mlxtend) (2.2.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from mlxtend) (3.10.6)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from mlxtend) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %% [markdown]
# You shall already be familiar with the concept of association rules and the apriori algorithm. Association rule mining is a method for discovering patterns within large data sets. It focuses on identifying relationships between variables and leveraging those connections to make predictions or informed decisions. The primary objective is to uncover rules that reveal the associations between various items in the data.

# %% [markdown]
# ### Task
# Load data from data.txt file - it contains lists of grocery shopping done by nearly 2000 customers.
# Store it in a boolean one hot encoded dataframe - True for items bought in a given transaction, False otherwise.

# %%
raw_data = {}

with open("data.txt", "r") as f:
    for i, line in enumerate(f, start=1):
        # Convert the string list into an actual Python list
        items = eval(line.strip())
        raw_data[i] = items

print(raw_data)
# Out:
# {1: ['milk', 'chicken', 'milk', 'chocolate', 'apple', 'banana', 'orange'], 2: ['milk', 'cheese', 'milk', 'yogurt'], 3: ['chicken'], 4: ['milk', 'pork'], 5: ['chicken'], 6: ['cheese', 'chicken', 'beef', 'sausage'], 7: ['milk', 'mustard'], 8: ['bread'], 9: ['cheese', 'beef', 'pork', 'grill', 'sausage', 'ketchup', 'apple', 'banana', 'orange'], 10: ['cheese', 'orange', 'chicken'], 11: ['bread', 'apple', 'banana', 'pork'], 12: ['apple', 'chicken'], 13: ['
'sausage', 'mustard'], 73: ['chicken', 'grill', 'sausage', 'ketchup'], 74: ['milk', 'chocolate', 'eggs'], 75: ['milk', 'apple', 'orange'], 76: ['milk'], 77: ['cheese', 'beef'], 78: ['milk', 'milk', 'yogurt'], 79: ['orange', 'beef'], 80: ['bread', 'apple', 'chicken', 'milk', 'chocolate', 'milk', 'yogurt'], 81: ['bread', 'cheese', 'apple', 'chicken'], 82: ['pork'], 83: ['apple', 'pork', 'sausage', 'milk', 'chocolate', 'grill', 'sausage', 'mustard', 'milk', 'yogurt'], 84: ['bread', 'chicken'], 85: ['eggs', 'chicken'], 86: ['beef'], 87: ['chicken', 'pork'], 88: ['bread', 'cheese', 'banana', 'orange', 'milk', 'chocolate', 'milk', 'yogurt'], 89: ['banana'], 90: ['beef'], 91: ['chicken', 'grill', 'sausage', 'mustard'], 92: ['cheese', 'pork', 'milk', 'yogurt'], 93: ['chicken'], 94: ['bread', 'sausage', 'grill', 'sausage', 'ketchup', 'apple', 'banana', 'orange'], 95: ['orange', 'chicken'], 96: ['milk', 'pork'], 97: ['yogurt', 'orange'], 98: ['bread', 'banana', 'chicken'], 99: ['chicken'], 100: ['bread', 'eggs', 'chicken', 'ketchup'], 101: ['cheese', 'banana', 'chicken'], 102: ['bread', 'orange', 'milk', 'chocolate'], 103: ['bread', 'milk', 'yogurt'], 104: ['bread', 'cheese', 'beef', 'sausage'], 105: ['bread', 'apple', 'chicken'], 106: ['bread', 'beef', 'sausage'], 107: ['chicken', 'pork', 'sausage', 'milk', 'chocolate'], 108: ['chicken', 'milk', 'yogurt'], 109: [ ...

# %% [markdown]
# To extract rules you can use e.g. apriori algorithm implemented in mlxtend. There are other algorithms performing the same task but using different approaches e.g. fpgrowth internally uses a tree-based structure which makes it faster in most real-life examples.

# %% [markdown]
# ### Task
# Find association rules using selected algorithm

# %% [markdown]
# ### Task
# The association rules are characterized by high support - frequency in the dataset. Can you use this algorithm as a base and try to extract different types of rules:
#  - dissociation rules e.g. buying Porshe and Rolex is not frequent in the dataset, but usually people who bought Porshe also bought Rolex
#  - negative rules e.g. if someone bought low-fat milk it's unlikely there will be whole milk in the basket
#  - disjunction e.g. eggs and (kielecki xor winiary ;) )
#  - imagine 50% of baskets have milk and 50% of baskets have tea. If there is no relation between them then in ~25% of baskets we will have both. If milk appears together with tea in e.g. 40% of baskets it means there is a pattern. Can you find such rules and use statistical tests to check if the relation is strong?
#
#  Send the report within 144 hours starting from the end of this class to gmiebs@cs.put.poznan.pl; start this email's subject with [IR]
