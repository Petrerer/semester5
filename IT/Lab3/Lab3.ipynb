# %%
# !pip install nltk
import nltk

from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize, wordpunct_tokenize

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\franc\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\franc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\franc\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\franc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# When working with a text you have to take into account families of words e.g. dog, dogs, doggy. The most popular techniques helping to deal with this issue are lemmatization and stemming. Both are special cases of normalization. They identify a canonical representative for a set of related word forms.
#
# The goal of both stemming and lemmatization is to reduce inflectional forms and sometimes derivationally related forms of a word to a common base form.
# However, the two words differ in their flavor. Stemming usually refers to a crude heuristic process that chops off the ends of words in the hope of achieving this goal correctly most of the time, and often includes the removal of derivational affixes. Lemmatization usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma.

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()
wordnet = WordNetLemmatizer()

# %%
print("{:15}{:15}{:15}{:15}".format("Word","Porter","Lancaster","WordNet"))
for word in ["was", "cats", "played", "mechanical", "friend", "friendship"]:
    print("{:15}{:15}{:15}{}".format(word, porter.stem(word), lancaster.stem(word), wordnet.lemmatize(word, pos="v")))
# Out:
# Word           Porter         Lancaster      WordNet
# was            wa             was            be
# cats           cat            cat            cat
# played         play           play           play
# mechanical     mechan         mech           mechanical
# friend         friend         friend         friend
# friendship     friendship     friend         friendship

# %%
text = """Poznań University of Technology, PUT (Polish name: Politechnika Poznańska) is a university in Poznań, 
Poland. Poznań University of Technology is known as one of the best technical universities in Poland. URAP 
ranked PUT as in top 6% of world universities and Webometrics ranked it at no. 842 in the world by Google 
citations for the year 2015. In 1995 it became the first Polish university to become a member of the Conference 
of European Schools for Advanced Engineering Education and Research (CESAER), an organization comprising the best 
technical universities in Europe. The university is also a member of the Socrates-Erasmus programme for exchange 
students from all over Europe, promoting advanced engineering and a European dimension. The university is home to 
many organizations and student circles, and the radio station Afera 98.6 MHz. The university has over 
21,000 students and over 1100 academic staffs.""".replace('\n',' ')

# %%
porter.stem(text)
# Out:
# 'poznań university of technology, put (polish name: politechnika poznańska) is a university in poznań,  poland. poznań university of technology is known as one of the best technical universities in poland. urap  ranked put as in top 6% of world universities and webometrics ranked it at no. 842 in the world by google  citations for the year 2015. in 1995 it became the first polish university to become a member of the conference  of european schools for advanced engineering education and research (cesaer), an organization comprising the best  technical universities in europe. the university is also a member of the socrates-erasmus programme for exchange  students from all over europe, promoting advanced engineering and a european dimension. the university is home to  many organizations and student circles, and the radio station afera 98.6 mhz. the university has over  21,000 students and over 1100 academic staffs.'

# %% [markdown]
# As a first step, we have to transform a string into a list of words. It's not as trivial as you might think. Thankfully there are libraries with such functions already implemented.

# %%
word_tokenize(text), len(word_tokenize(text))
# Out:
# (['Poznań',
#   'University',
#   'of',
#   'Technology',
#   ',',
#   'PUT',
#   '(',
#   'Polish',
#   'name',
#   ':',
#   'Politechnika',
#   'Poznańska',
#   ')',
#   'is',
#   'a',
#   'university',
#   'in',
#   'Poznań',
#   ',',
#   'Poland',
#   '.',
#   'Poznań',
#   'University',
#   'of',
#   'Technology',
#   'is',
#   'known',
#   'as',
#   'one',
#   'of',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Poland',
#   '.',
#   'URAP',
#   'ranked',
#   'PUT',
#   'as',
#   'in',
#   'top',
#   '6',
#   '%',
#   'of',
#   'world',
#   'universities',
#   'and',
#   'Webometrics',
#   'ranked',
#   'it',
#   'at',
#   'no',
#   '.',
#   '842',
#   'in',
#   'the',
#   'world',
#   'by',
#   'Google',
#   'citations',
#   'for',
#   'the',
#   'year',
#   '2015',
#   '.',
#   'In',
#   '1995',
#   'it',
#   'became',
#   'the',
#   'first',
#   'Polish',
#   'university',
#   'to',
#   'become',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Conference',
#   'of',
#   'European',
#   'Schools',
#   'for',
#   'Advanced',
#   'Engineering',
#   'Education',
#   'and',
#   'Research',
#   '(',
#   'CESAER',
#   ')',
#   ',',
#   'an',
#   'organization',
#   'comprising',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Europe',
#   '.',
#   'The',
#   'university',
#   'is',
#   'also',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Socrates-Erasmus',
#   'programme',
#   'for',
#   'exchange',
#   'students',
#   'from',
#   'all',
#   'over',
#   'Europe',
#   ',',
#   'promoting',
#   'advanced',
#   'engineering',
#   'and',
#   'a',
#   'European',
#   'dimension',
#   '.',
#   'The',
#   'university',
#   'is',
#   'home',
#   'to',
#   'many',
#   'organizations',
#   'and',
#   'student',
#   'circles',
#   ',',
#   'and',
#   'the',
#   'radio',
#   'station',
#   'Afera',
#   '98.6',
#   'MHz',
#   '.',
#   'The',
#   'university',
#   'has',
#   'over',
#   '21,000',
#   'students',
#   'and',
#   'over',
#   '1100',
#   'academic',
#   'staffs',
#   '.'],
#  162)

# %%
wordpunct_tokenize(text), len(wordpunct_tokenize(text))
# Out:
# (['Poznań',
#   'University',
#   'of',
#   'Technology',
#   ',',
#   'PUT',
#   '(',
#   'Polish',
#   'name',
#   ':',
#   'Politechnika',
#   'Poznańska',
#   ')',
#   'is',
#   'a',
#   'university',
#   'in',
#   'Poznań',
#   ',',
#   'Poland',
#   '.',
#   'Poznań',
#   'University',
#   'of',
#   'Technology',
#   'is',
#   'known',
#   'as',
#   'one',
#   'of',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Poland',
#   '.',
#   'URAP',
#   'ranked',
#   'PUT',
#   'as',
#   'in',
#   'top',
#   '6',
#   '%',
#   'of',
#   'world',
#   'universities',
#   'and',
#   'Webometrics',
#   'ranked',
#   'it',
#   'at',
#   'no',
#   '.',
#   '842',
#   'in',
#   'the',
#   'world',
#   'by',
#   'Google',
#   'citations',
#   'for',
#   'the',
#   'year',
#   '2015',
#   '.',
#   'In',
#   '1995',
#   'it',
#   'became',
#   'the',
#   'first',
#   'Polish',
#   'university',
#   'to',
#   'become',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Conference',
#   'of',
#   'European',
#   'Schools',
#   'for',
#   'Advanced',
#   'Engineering',
#   'Education',
#   'and',
#   'Research',
#   '(',
#   'CESAER',
#   '),',
#   'an',
#   'organization',
#   'comprising',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Europe',
#   '.',
#   'The',
#   'university',
#   'is',
#   'also',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Socrates',
#   '-',
#   'Erasmus',
#   'programme',
#   'for',
#   'exchange',
#   'students',
#   'from',
#   'all',
#   'over',
#   'Europe',
#   ',',
#   'promoting',
#   'advanced',
#   'engineering',
#   'and',
#   'a',
#   'European',
#   'dimension',
#   '.',
#   'The',
#   'university',
#   'is',
#   'home',
#   'to',
#   'many',
#   'organizations',
#   'and',
#   'student',
#   'circles',
#   ',',
#   'and',
#   'the',
#   'radio',
#   'station',
#   'Afera',
#   '98',
#   '.',
#   '6',
#   'MHz',
#   '.',
#   'The',
#   'university',
#   'has',
#   'over',
#   '21',
#   ',',
#   '000',
#   'students',
#   'and',
#   'over',
#   '1100',
#   'academic',
#   'staffs',
#   '.'],
#  167)

# %%
for x in word_tokenize(text):
    print("{:20} - {:20}".format(x, porter.stem(x)))
# Out:
# Poznań               - poznań
# University           - univers
# of                   - of
# Technology           - technolog
# ,                    - ,
# PUT                  - put
# (                    - (
# Polish               - polish
# name                 - name
# :                    - :
# Politechnika         - politechnika
# Poznańska            - poznańska
# )                    - )
# is                   - is
# a                    - a
# university           - univers
# in                   - in
# Poznań               - poznań
# ,                    - ,
# Poland               - poland
# .                    - .
# Poznań               - poznań
# University           - univers
# of                   - of
# Technology           - technolog
# is                   - is
# known                - known
# as                   - as
# one                  - one
# of                   - of
# the                  - the
# best                 - best
# technical            - technic
# universities         - univers
# in                   - in
# Poland               - poland
# .                    - .
# URAP                 - urap
# ranked               - rank
# PUT                  - put
# as                   - as
# in                   - in
# top                  - top
# 6                    - 6
# %                    - %
# of                   - of
# world                - world
# universities         - univers
# and                  - and
# Webometrics          - webometr
# ranked               - rank
# it                   - it
# at                   - at
# no                   - no
# .                    - .
# 842                  - 842
# in                   - in
# the                  - the
# world                - world
# by                   - by
# Google               - googl
# citations            - citat
# for                  - for
# the                  - the
# year                 - year
# 2015                 - 2015
# .                    - .
# In                   - in
# 1995                 - 1995
# it                   - it
# became               - becam
# the                  - the
# first                - first
# Polish               - polish
# university           - univers
# to                   - to
# become               - becom
# a                    - a
# member               - member
# of                   - of
# the                  - the
# Conference           - confer
# of                   - of
# European             - european
# Schools              - school
# for                  - for
# Advanced             - advanc
# Engineering          - engin
# Education            - educ
# and                  - and
# Research             - research
# (                    - (
# CESAER               - cesaer
# )                    - )
# ,                    - ,
# an                   - an
# organization         - organ
# comprising           - compris
# the                  - the
# best                 - best
# technical            - technic
# universities         - univers
# in                   - in
# Europe               - europ
# .                    - .
# The                  - the
# university           - univers
# is                   - is
# also                 - also
# a                    - a
# member               - member
# of                   - of
# the                  - the
# Socrates-Erasmus     - socrates-erasmu
# programme            - programm
# for                  - for
# exchange             - exchang
# students             - student
# from                 - from
# all                  - all
# over                 - over
# Europe               - europ
# ,                    - ,
# promoting            - promot
# advanced             - advanc
# engineering          - engin
# and                  - and
# a                    - a
# European             - european
# dimension            - dimens
# .                    - .
# The                  - the
# university           - univers
# is                   - is
# home                 - home
# to                   - to
# many                 - mani
# organizations        - organ
# and                  - and
# student              - student
# circles              - circl
# ,                    - ,
# and                  - and
# the                  - the
# radio                - radio
# station              - station
# Afera                - afera
# 98.6                 - 98.6
# MHz                  - mhz
# .                    - .
# The                  - the
# university           - univers
# has                  - ha
# over                 - over
# 21,000               - 21,000
# students             - student
# and                  - and
# over                 - over
# 1100                 - 1100
# academic             - academ
# staffs               - staff
# .                    - .

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# ## Task
# Write function which takes string as input and returns list of stems for reasonable words. Filter out stop words and non-words.

# %%
def custom_stemmer(string):
    tokens = []
    for x in word_tokenize(string):
        tokens.append(porter.stem(x))

    alphabetic_tokens = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890'
    tokens_filtered =[]
    for x in tokens:
        if x not in stopwords.words('english') and all(c in alphabetic_tokens for c in x):
            tokens_filtered.append(x)
    return tokens_filtered

# %%
custom_stemmer(text)
# Out:
# ['univers',
#  'technolog',
#  'put',
#  'polish',
#  'name',
#  'politechnika',
#  'univers',
#  'poland',
#  'univers',
#  'technolog',
#  'known',
#  'one',
#  'best',
#  'technic',
#  'univers',
#  'poland',
#  'urap',
#  'rank',
#  'put',
#  'top',
#  '6',
#  'world',
#  'univers',
#  'webometr',
#  'rank',
#  '842',
#  'world',
#  'googl',
#  'citat',
#  'year',
#  '2015',
#  '1995',
#  'becam',
#  'first',
#  'polish',
#  'univers',
#  'becom',
#  'member',
#  'confer',
#  'european',
#  'school',
#  'advanc',
#  'engin',
#  'educ',
#  'research',
#  'cesaer',
#  'organ',
#  'compris',
#  'best',
#  'technic',
#  'univers',
#  'europ',
#  'univers',
#  'also',
#  'member',
#  'programm',
#  'exchang',
#  'student',
#  'europ',
#  'promot',
#  'advanc',
#  'engin',
#  'european',
#  'dimens',
#  'univers',
#  'home',
#  'mani',
#  'organ',
#  'student',
#  'circl',
#  'radio',
#  'station',
#  'afera',
#  'mhz',
#  'univers',
#  'ha',
#  'student',
#  '1100',
#  'academ',
#  'staff']

# %% [markdown]
# ## Task
# Convert a date of yyyy-mm-dd format to dd.mm.yyyy format using regular expresions

# %%
import re

s = ["1985-12-4",
    "asd 12-132-133",
    "Afs!@#-2055-12-12",
    "02-03-2020",
    "Is it a date 2012-11-01?"]

# %% [markdown]
# The following output is expected:
#
# 4.12.1985<br>
# asd 12-132-133<br>
# Afs!@#-12.12.2055<br>
# 02-03-2020<br>
# Is it a date 01.11.2012?<br>
#
# Use re.sub function

# %%
for x in s:
    x = re.sub(r'(\d{4})-(\d{1,2})-(\d{1,2})', r'\g<3>.\g<2>.\g<1>', x)
    print(x)
# Out:
# 4.12.1985
# asd 12-132-133
# Afs!@#-12.12.2055
# 02-03-2020
# Is it a date 01.11.2012?

# %% [markdown]
# # OCR

# %%
# !pip install pytesseract pillow numpy opencv-python requests
import pytesseract
from PIL import Image
import numpy as np
import cv2
import requests
from io import BytesIO

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
# Out:
# Requirement already satisfied: pytesseract in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (0.3.13)
# Requirement already satisfied: pillow in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (11.2.1)
# Requirement already satisfied: numpy in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (2.2.5)
# Requirement already satisfied: opencv-python in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (4.12.0.88)
# Requirement already satisfied: requests in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (2.32.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\franc\onedrive\desktop\exist project\exist-project\.conda\lib\site-packages (from requests) (2025.8.3)

# %%
url = "https://i.ibb.co/8d564bB/example-01.png"

response = requests.get(url)
img = Image.open(BytesIO(response.content))

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x250>

# %%
print(pytesseract.image_to_string(img))
# Out:
# Noisyimage
# to test
# Tesseract OCR

# %%
url = "https://i.ibb.co/n63mZfb/example-02.png"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x250>

# %%
print(pytesseract.image_to_string(img))
# Out:
# _ Tesseract Will
# Fail With Noisy
# _ Backgrounds —

# %% [markdown]
# ## Task
# Read perfectly text from example_02

# %%
import cv2
import matplotlib.pyplot as plt

# %%
response = requests.get("https://i.ibb.co/n63mZfb/example-02.png")
img = Image.open(BytesIO(response.content))
img = cv2.cvtColor(np.array(img), cv2.COLOR_RGBA2GRAY)
figure, ax = plt.subplots(1,3, figsize=(15, 5))
ax[0].imshow(img, cmap='gray')

kernel = np.ones((3, 3), np.uint8)
img = cv2.erode(img, kernel)
ax[1].imshow(img, cmap='gray')

kernel = np.ones((3, 3), np.uint8)
img = -cv2.erode(-img, kernel)
ax[2].imshow(img, cmap='gray')

print(pytesseract.image_to_string(img))
# Out:
# Tesseract Will
# Fail With Noisy
# Backgrounds

# %%
print(pytesseract.image_to_string(img))
# Out:
# ‘Tesseract Will -
# aN With nin

# %% [markdown]
# ## Task 5
# Read nearly perfectly text from vin.png, 1 error allowed (missing char, additional char, wrong char), 0/O is not an error

# %%
response = requests.get("https://i.ibb.co/1ffsFkx/vin.png")
img = Image.open(BytesIO(response.content))
img = cv2.cvtColor(np.array(img), cv2.COLOR_RGBA2GRAY)
figure, ax = plt.subplots(1,4, figsize=(15, 5))
ax[0].imshow(img, cmap='gray')

kernel = np.ones((7, 7), np.uint8)
img = cv2.erode(img, kernel)
ax[1].imshow(img, cmap='gray')

kernel = np.ones((5, 5), np.uint8)
img = -cv2.erode(-img, kernel)
ax[2].imshow(img, cmap='gray')

img = cv2.threshold(img, 123, 255, cv2.THRESH_BINARY)[1]
ax[3].imshow(img, cmap='gray')

print(pytesseract.image_to_string(img))
# Out:
# MRHRW5810KP102174
